# %% [markdown]
# <h6 align=right> 🐍 Python akademie - lekce 12 - 17.05.2023</h6>
#
# ---

# %% [markdown]
# <br>
#
# # <h1 align=center><font size=24><b> 12_03: API</font></h1>
#
# <br>

# %% [markdown]
# **API** znamená **Application Programming Interface** a slouží k propojení různých softwarových aplikací a systémů. Je to taková vrstva mezi dvěma aplikacemi, která umožňuje, aby si tyto aplikace mezi sebou mohly vyměňovat data a informace.
#
# <br>
#
# API se dá použít na různé účely. Například:
#
# <br>
#
# 1. Integrace aplikací: API umožňuje dvěma různým aplikacím komunikovat a vyměňovat si data. To je užitečné v případech, kdy chcete vytvořit aplikaci, která bude využívat data z jiné aplikace.
#
# 2. Automatizace: API umožňuje automatizovat určité procesy, což může být užitečné v případech, kdy chcete zjednodušit nebo zefektivnit nějakou práci.
#
# 3. Vývoj webových stránek a mobilních aplikací: API umožňuje vývojářům webových stránek a mobilních aplikací využívat funkce a data z jiných aplikací a služeb, což může zlepšit uživatelskou zkušenost a zvýšit efektivitu vývoje.
#
# 4. Vývoj chatbotů a dalších automatizovaných systémů: API umožňuje chatbotům a dalším automatizovaným systémům komunikovat s jinými aplikacemi a službami, což může pomoci vytvářet sofistikovanější a užitečnější řešení pro uživatele.
#
# <br>
#
# Celkově lze říci, že API je velmi užitečný nástroj pro propojení různých aplikací a systémů a umožňuje vytvářet sofistikovanější a efektivnější řešení pro uživatele.

# %% [markdown]
# <br>
#
# ## **Práce s API**
#
# Obecně vzato, práce s API vypadá následovně:
#
# 1. Registrace a získání přístupových údajů - Než budete moci používat API, budete muset se zaregistrovat a získat přístupové údaje (klíče) od poskytovatele API. Tyto klíče vám umožní přistupovat k datům a funkcím, které API nabízí.
#
# 2. Výběr a implementace konkrétních volání API - Každé API má své vlastní funkce, které můžete použít. Výběr a implementace konkrétních volání API závisí na vašich potřebách a požadavcích aplikace.
#
# 3. Vytvoření HTTP požadavku - Když budete chtít získat data z API nebo nějakou funkci zavolat, musíte vytvořit HTTP požadavek na server, kde API běží. Požadavek může obsahovat parametry jako například ID položky, kterou chcete získat, nebo data, která chcete zaslat na server.
#
# 4. Zpracování HTTP odpovědi - Když API obdrží váš požadavek, odešle vám odpověď ve formátu JSON nebo XML. Musíte tedy zpracovat tuto odpověď a získat z ní data, která potřebujete.
#
# 5. Manipulace s daty - Po získání dat z API je můžete dále manipulovat, zpracovávat a zobrazovat ve vaší aplikaci.
#
# <br>
#
# Je důležité si uvědomit, že každé API má svá specifika a různou úroveň složitosti. Některá API mohou být velmi jednoduchá a snadno použitelná, zatímco jiná mohou být složitější a vyžadovat větší úroveň technických znalostí.

# %% [markdown]
# <br>
#
# ## **Příklad místo řečí**
#
# * Chci získat tabulku hráčů z webu https://aoe2.net/
# * Podívám se, jestli neposkytuje API
# * Přečtu si dokumentaci

# %%
import requests
from pprint import pprint

url = 'https://aoe2.net/api/leaderboard'
params = {
    'game': 'aoe2de', 
    'leaderboard_id': '3', 
    'start':'1',
    'count':'100'
    }

# headers = {
    # 'Authorization': 'Bearer token123'
    # }
    
response = requests.get(
    url, 
    params=params, 
    # headers=headers
    )

if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print('Chyba při získávání dat')
# Out:
# {'count': 100,
#  'leaderboard': [{'clan': None,
#                   'country': 'NO',
#                   'drops': 96,
#                   'games': 4403,
#                   'highest_rating': 2798,
#                   'highest_streak': 23,
#                   'icon': None,
#                   'last_match_time': 1684277063,
#                   'losses': 1340,
#                   'lowest_streak': -9,
#                   'name': '[aM]MbL40C',
#                   'previous_rating': 2791,
#                   'profile_id': 251265,
#                   'rank': 1,
#                   'rating': 2798,
#                   'steam_id': '76561197996386232',
#                   'streak': 10,
#                   'wins': 3063},
#                  {'clan': None,
#                   'country': 'NO',
#                   'drops': 5,
#                   'games': 560,
#                   'highest_rating': 2762,
#                   'highest_streak': 73,
#                   'icon': None,
#                   'last_match_time': 1684023756,
#                   'losses': 129,
#                   'lowest_streak': -10,
#                   'name': '___MbL___',
#                   'previous_rating': 2750,
#                   'profile_id': 4422938,
#                   'rank': 2,
#                   'rating': 2762,
#                   'steam_id': '76561199118807671',
#                   'streak': 9,
#                   'wins': 431},
#                  {'clan': None,
#                   'country': 'CA',
#                   'drops': 30,
#                   'games': 3633,
#                   'highest_rating': 2838,
#                   'highest_streak': 36,
#                   'icon': None,
#                   'last_match_time': 1684106139,
#                   'losses': 1067,
#                   'lowest_streak': -6,
#                   'name': '[aM] Hera',
#                   'previous_rating': 2757,
#                   'profile_id': 199325,
#                   'rank': 3,
#                   'rating': 2758,
#                   'steam_id': '76561198449406083',
#                   'streak': 6,
#                   'wins': 2566},
#                  {'clan': None,
#                   'country': 'NO',
#                   'drops': 9,
#                   'games': 1048,
#                   'highest_rating': 2756,
#                   'highest_streak': 39,
#                   'icon': None,
#                   'last_match_time': 1684191451,
#                   'losses': 258,
#                   'lowest_streak': -5,
#                   'name': '__TheMbL__',
#                   'previous_rating': 2754,
#                   'profile_id': 2644601,
#                   'rank': 4,
#                   'rating': 2756,
#                   'steam_id': '76561199057707367',
#                   'streak': 6,
#                   'wins': 790},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 17,
#                   'games': 1746,
#                   'highest_rating': 2707,
#                   'highest_streak': 32,
#                   'icon': None,
#                   'last_match_time': 1683745630,
#                   'losses': 446,
#                   'lowest_streak': -5,
#                   'name': 'dogao',
#                   'previous_rating': 2691,
#                   'profile_id': 199170,
#                   'rank': 5,
#                   'rating': 2707,
#                   'steam_id': '76561197992981071',
#                   'streak': 15,
#                   'wins': 1300},
#                  {'clan': 'WWP',
#                   'country': 'CN',
#                   'drops': 22,
#                   'games': 2370,
#                   'highest_rating': 2799,
#                   'highest_streak': 15,
#                   'icon': None,
#                   'last_match_time': 1684244863,
#                   'losses': 864,
#                   'lowest_streak': -7,
#                   'name': 'Yo',
#                   'previous_rating': 2701,
#                   'profile_id': 197964,
#                   'rank': 6,
#                   'rating': 2704,
#                   'steam_id': '76561198179087382',
#                   'streak': 3,
#                   'wins': 1506},
#                  {'clan': None,
#                   'country': 'NO',
#                   'drops': 4,
#                   'games': 1656,
#                   'highest_rating': 2813,
#                   'highest_streak': 22,
#                   'icon': None,
#                   'last_match_time': 1684324063,
#                   'losses': 566,
#                   'lowest_streak': -9,
#                   'name': 'GL.TheViper',
#                   'previous_rating': 2697,
#                   'profile_id': 196240,
#                   'rank': 7,
#                   'rating': 2699,
#                   'steam_id': '76561197984749679',
#                   'streak': 2,
#                   'wins': 1090},
#                  {'clan': None,
#                   'country': 'SI',
#                   'drops': 2,
#                   'games': 680,
#                   'highest_rating': 2717,
#                   'highest_streak': 24,
#                   'icon': None,
#                   'last_match_time': 1683985636,
#                   'losses': 258,
#                   'lowest_streak': -6,
#                   'name': 'Modri',
#                   'previous_rating': 2717,
#                   'profile_id': 1862892,
#                   'rank': 8,
#                   'rating': 2696,
#                   'steam_id': '76561199032160044',
#                   'streak': -1,
#                   'wins': 422},
#                  {'clan': 'FrCo',
#                   'country': 'FR',
#                   'drops': 6,
#                   'games': 1152,
#                   'highest_rating': 2711,
#                   'highest_streak': 29,
#                   'icon': None,
#                   'last_match_time': 1684331044,
#                   'losses': 355,
#                   'lowest_streak': -5,
#                   'name': 'mYi.Sitaux',
#                   'previous_rating': 2674,
#                   'profile_id': 212721,
#                   'rank': 9,
#                   'rating': 2684,
#                   'steam_id': '76561198116921964',
#                   'streak': 6,
#                   'wins': 797},
#                  {'clan': 'FrCo',
#                   'country': 'FR',
#                   'drops': 1,
#                   'games': 321,
#                   'highest_rating': 2679,
#                   'highest_streak': 40,
#                   'icon': None,
#                   'last_match_time': 1683729981,
#                   'losses': 76,
#                   'lowest_streak': -4,
#                   'name': 'mYi.Sitaux',
#                   'previous_rating': 2667,
#                   'profile_id': 4351237,
#                   'rank': 10,
#                   'rating': 2679,
#                   'steam_id': '76561199114437308',
#                   'streak': 13,
#                   'wins': 245},
#                  {'clan': None,
#                   'country': 'CN',
#                   'drops': 1,
#                   'games': 336,
#                   'highest_rating': 2672,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1683911156,
#                   'losses': 97,
#                   'lowest_streak': -4,
#                   'name': 'vivi_NOOB',
#                   'previous_rating': 2656,
#                   'profile_id': 11406458,
#                   'rank': 11,
#                   'rating': 2672,
#                   'steam_id': '76561199406815843',
#                   'streak': 5,
#                   'wins': 239},
#                  {'clan': None,
#                   'country': 'CA',
#                   'drops': 0,
#                   'games': 300,
#                   'highest_rating': 2757,
#                   'highest_streak': 45,
#                   'icon': None,
#                   'last_match_time': 1684187178,
#                   'losses': 69,
#                   'lowest_streak': -4,
#                   'name': 'Arabia Player',
#                   'previous_rating': 2684,
#                   'profile_id': 3209724,
#                   'rank': 12,
#                   'rating': 2671,
#                   'steam_id': '76561198410119452',
#                   'streak': -4,
#                   'wins': 231},
#                  {'clan': None,
#                   'country': 'PE',
#                   'drops': 21,
#                   'games': 2548,
#                   'highest_rating': 2732,
#                   'highest_streak': 14,
#                   'icon': None,
#                   'last_match_time': 1684058795,
#                   'losses': 979,
#                   'lowest_streak': -7,
#                   'name': '[aM] Hearttt',
#                   'previous_rating': 2662,
#                   'profile_id': 582058,
#                   'rank': 13,
#                   'rating': 2670,
#                   'steam_id': '76561198032611326',
#                   'streak': 8,
#                   'wins': 1569},
#                  {'clan': None,
#                   'country': 'FI',
#                   'drops': 16,
#                   'games': 2863,
#                   'highest_rating': 2740,
#                   'highest_streak': 19,
#                   'icon': None,
#                   'last_match_time': 1683815715,
#                   'losses': 986,
#                   'lowest_streak': -7,
#                   'name': 'Villese',
#                   'previous_rating': 2643,
#                   'profile_id': 208611,
#                   'rank': 14,
#                   'rating': 2661,
#                   'steam_id': '76561198325239137',
#                   'streak': 1,
#                   'wins': 1877},
#                  {'clan': None,
#                   'country': 'RU',
#                   'drops': 7,
#                   'games': 1488,
#                   'highest_rating': 2742,
#                   'highest_streak': 18,
#                   'icon': None,
#                   'last_match_time': 1684253961,
#                   'losses': 457,
#                   'lowest_streak': -6,
#                   'name': 'SalzZ_Vinchester',
#                   'previous_rating': 2651,
#                   'profile_id': 271202,
#                   'rank': 15,
#                   'rating': 2657,
#                   'steam_id': '76561198000635167',
#                   'streak': 3,
#                   'wins': 1031},
#                  {'clan': None,
#                   'country': 'AR',
#                   'drops': 8,
#                   'games': 1608,
#                   'highest_rating': 2730,
#                   'highest_streak': 22,
#                   'icon': None,
#                   'last_match_time': 1684302018,
#                   'losses': 453,
#                   'lowest_streak': -6,
#                   'name': '[aM] Nicov',
#                   'previous_rating': 2647,
#                   'profile_id': 208393,
#                   'rank': 16,
#                   'rating': 2653,
#                   'steam_id': '76561198027378107',
#                   'streak': 4,
#                   'wins': 1155},
#                  {'clan': None,
#                   'country': 'DE',
#                   'drops': 8,
#                   'games': 1964,
#                   'highest_rating': 2652,
#                   'highest_streak': 27,
#                   'icon': None,
#                   'last_match_time': 1684240660,
#                   'losses': 760,
#                   'lowest_streak': -6,
#                   'name': 'Running',
#                   'previous_rating': 2640,
#                   'profile_id': 4620061,
#                   'rank': 17,
#                   'rating': 2652,
#                   'steam_id': '76561199124381546',
#                   'streak': 7,
#                   'wins': 1204},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 6,
#                   'games': 1509,
#                   'highest_rating': 2632,
#                   'highest_streak': 20,
#                   'icon': None,
#                   'last_match_time': 1683929255,
#                   'losses': 417,
#                   'lowest_streak': -6,
#                   'name': 'doguinhoCaRaMeLo_xD_br_2k',
#                   'previous_rating': 2627,
#                   'profile_id': 1486575,
#                   'rank': 18,
#                   'rating': 2631,
#                   'steam_id': '76561199021127843',
#                   'streak': 2,
#                   'wins': 1092},
#                  {'clan': None,
#                   'country': 'PL',
#                   'drops': 12,
#                   'games': 2674,
#                   'highest_rating': 2697,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684271308,
#                   'losses': 989,
#                   'lowest_streak': -7,
#                   'name': '_Barles_',
#                   'previous_rating': 2642,
#                   'profile_id': 666976,
#                   'rank': 19,
#                   'rating': 2623,
#                   'steam_id': '76561198275359848',
#                   'streak': -1,
#                   'wins': 1685},
#                  {'clan': None,
#                   'country': 'AT',
#                   'drops': 9,
#                   'games': 1044,
#                   'highest_rating': 2659,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1683903949,
#                   'losses': 342,
#                   'lowest_streak': -6,
#                   'name': '[aM] Liereyy',
#                   'previous_rating': 2618,
#                   'profile_id': 506898,
#                   'rank': 20,
#                   'rating': 2606,
#                   'steam_id': '76561198362219694',
#                   'streak': -2,
#                   'wins': 702},
#                  {'clan': None,
#                   'country': 'FI',
#                   'drops': 2,
#                   'games': 2034,
#                   'highest_rating': 2645,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1684317014,
#                   'losses': 846,
#                   'lowest_streak': -7,
#                   'name': 'Valas',
#                   'previous_rating': 2599,
#                   'profile_id': 628503,
#                   'rank': 21,
#                   'rating': 2604,
#                   'steam_id': '76561198036586732',
#                   'streak': 7,
#                   'wins': 1188},
#                  {'clan': 'DauT',
#                   'country': 'RS',
#                   'drops': 15,
#                   'games': 2238,
#                   'highest_rating': 2626,
#                   'highest_streak': 30,
#                   'icon': None,
#                   'last_match_time': 1684157242,
#                   'losses': 931,
#                   'lowest_streak': -9,
#                   'name': 'GL.DauT',
#                   'previous_rating': 2594,
#                   'profile_id': 198035,
#                   'rank': 22,
#                   'rating': 2580,
#                   'steam_id': '76561198044559189',
#                   'streak': -2,
#                   'wins': 1307},
#                  {'clan': None,
#                   'country': 'VN',
#                   'drops': 45,
#                   'games': 3394,
#                   'highest_rating': 2668,
#                   'highest_streak': 25,
#                   'icon': None,
#                   'last_match_time': 1684225539,
#                   'losses': 1055,
#                   'lowest_streak': -7,
#                   'name': 'Gamdom.ACCM |AOEBuilds.com',
#                   'previous_rating': 2585,
#                   'profile_id': 347269,
#                   'rank': 23,
#                   'rating': 2571,
#                   'steam_id': '76561198364718180',
#                   'streak': -1,
#                   'wins': 2339},
#                  {'clan': None,
#                   'country': 'DE',
#                   'drops': 13,
#                   'games': 1875,
#                   'highest_rating': 2760,
#                   'highest_streak': 27,
#                   'icon': None,
#                   'last_match_time': 1684331005,
#                   'losses': 779,
#                   'lowest_streak': -10,
#                   'name': 'GL.JorDan_AoE',
#                   'previous_rating': 2549,
#                   'profile_id': 2858362,
#                   'rank': 24,
#                   'rating': 2561,
#                   'steam_id': '76561198400058723',
#                   'streak': 1,
#                   'wins': 1096},
#                  {'clan': None,
#                   'country': 'UA',
#                   'drops': 11,
#                   'games': 1706,
#                   'highest_rating': 2581,
#                   'highest_streak': 22,
#                   'icon': None,
#                   'last_match_time': 1684329288,
#                   'losses': 642,
#                   'lowest_streak': -8,
#                   'name': 'SalzZ_classicpro',
#                   'previous_rating': 2566,
#                   'profile_id': 1754629,
#                   'rank': 25,
#                   'rating': 2559,
#                   'steam_id': '76561198807828662',
#                   'streak': 1,
#                   'wins': 1064},
#                  {'clan': 'Biry',
#                   'country': 'UY',
#                   'drops': 25,
#                   'games': 2126,
#                   'highest_rating': 2603,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684345413,
#                   'losses': 956,
#                   'lowest_streak': -7,
#                   'name': 'DS_Sebastian',
#                   'previous_rating': 2539,
#                   'profile_id': 2783660,
#                   'rank': 26,
#                   'rating': 2552,
#                   'steam_id': '76561199062883266',
#                   'streak': 2,
#                   'wins': 1170},
#                  {'clan': 'ROTLD',
#                   'country': 'RO',
#                   'drops': 49,
#                   'games': 4053,
#                   'highest_rating': 2578,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684242452,
#                   'losses': 1884,
#                   'lowest_streak': -9,
#                   'name': 'Mihai06',
#                   'previous_rating': 2539,
#                   'profile_id': 288714,
#                   'rank': 27,
#                   'rating': 2550,
#                   'steam_id': '76561198282860959',
#                   'streak': 1,
#                   'wins': 2169},
#                  {'clan': 'FrCo',
#                   'country': 'FR',
#                   'drops': 13,
#                   'games': 1173,
#                   'highest_rating': 2604,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1682810122,
#                   'losses': 492,
#                   'lowest_streak': -7,
#                   'name': 'Fox.Margougou',
#                   'previous_rating': 2604,
#                   'profile_id': 2368761,
#                   'rank': 28,
#                   'rating': 2549,
#                   'steam_id': '76561199047138712',
#                   'streak': 5,
#                   'wins': 681},
#                  {'clan': 'SINGE',
#                   'country': 'FR',
#                   'drops': 16,
#                   'games': 1782,
#                   'highest_rating': 2579,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684244988,
#                   'losses': 782,
#                   'lowest_streak': -7,
#                   'name': 'Fox.Margougou',
#                   'previous_rating': 2501,
#                   'profile_id': 579679,
#                   'rank': 29,
#                   'rating': 2521,
#                   'steam_id': '76561198425688505',
#                   'streak': 1,
#                   'wins': 1000},
#                  {'clan': 'TaToH',
#                   'country': 'ES',
#                   'drops': 4,
#                   'games': 869,
#                   'highest_rating': 2605,
#                   'highest_streak': 32,
#                   'icon': None,
#                   'last_match_time': 1683644977,
#                   'losses': 245,
#                   'lowest_streak': -6,
#                   'name': 'GL.TaToH',
#                   'previous_rating': 2515,
#                   'profile_id': 197388,
#                   'rank': 30,
#                   'rating': 2518,
#                   'steam_id': '76561198088251629',
#                   'streak': 1,
#                   'wins': 624},
#                  {'clan': 'Combi',
#                   'country': 'MX',
#                   'drops': 30,
#                   'games': 2927,
#                   'highest_rating': 2512,
#                   'highest_streak': 20,
#                   'icon': None,
#                   'last_match_time': 1684138438,
#                   'losses': 1425,
#                   'lowest_streak': -8,
#                   'name': 'Combi | Uzzi',
#                   'previous_rating': 2499,
#                   'profile_id': 229071,
#                   'rank': 31,
#                   'rating': 2512,
#                   'steam_id': '76561198217460091',
#                   'streak': 4,
#                   'wins': 1502},
#                  {'clan': None,
#                   'country': 'AR',
#                   'drops': 14,
#                   'games': 1567,
#                   'highest_rating': 2576,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1684210518,
#                   'losses': 625,
#                   'lowest_streak': -6,
#                   'name': 'Capoch',
#                   'previous_rating': 2485,
#                   'profile_id': 409748,
#                   'rank': 32,
#                   'rating': 2509,
#                   'steam_id': '76561198099659716',
#                   'streak': 6,
#                   'wins': 942},
#                  {'clan': None,
#                   'country': 'HK',
#                   'drops': 4,
#                   'games': 347,
#                   'highest_rating': 2496,
#                   'highest_streak': 34,
#                   'icon': None,
#                   'last_match_time': 1684242819,
#                   'losses': 119,
#                   'lowest_streak': -5,
#                   'name': 'Kalong亲卫队队长',
#                   'previous_rating': 2487,
#                   'profile_id': 10336997,
#                   'rank': 33,
#                   'rating': 2496,
#                   'steam_id': '76561199326626083',
#                   'streak': 5,
#                   'wins': 228},
#                  {'clan': None,
#                   'country': 'UA',
#                   'drops': 1,
#                   'games': 116,
#                   'highest_rating': 2565,
#                   'highest_streak': 38,
#                   'icon': None,
#                   'last_match_time': 1683287622,
#                   'losses': 17,
#                   'lowest_streak': -4,
#                   'name': 'GG',
#                   'previous_rating': 2523,
#                   'profile_id': 14665996,
#                   'rank': 34,
#                   'rating': 2495,
#                   'steam_id': '76561199153076089',
#                   'streak': -1,
#                   'wins': 99},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 12,
#                   'games': 2375,
#                   'highest_rating': 2557,
#                   'highest_streak': 22,
#                   'icon': None,
#                   'last_match_time': 1684174604,
#                   'losses': 1020,
#                   'lowest_streak': -10,
#                   'name': 'miguel',
#                   'previous_rating': 2489,
#                   'profile_id': 2090225,
#                   'rank': 35,
#                   'rating': 2495,
#                   'steam_id': '76561198242526658',
#                   'streak': 2,
#                   'wins': 1355},
#                  {'clan': None,
#                   'country': 'VN',
#                   'drops': 66,
#                   'games': 3233,
#                   'highest_rating': 2517,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1684216693,
#                   'losses': 1157,
#                   'lowest_streak': -7,
#                   'name': 'saymyname',
#                   'previous_rating': 2517,
#                   'profile_id': 419803,
#                   'rank': 36,
#                   'rating': 2494,
#                   'steam_id': '76561198419918984',
#                   'streak': -1,
#                   'wins': 2076},
#                  {'clan': None,
#                   'country': 'CA',
#                   'drops': 0,
#                   'games': 425,
#                   'highest_rating': 2489,
#                   'highest_streak': 20,
#                   'icon': None,
#                   'last_match_time': 1683601547,
#                   'losses': 132,
#                   'lowest_streak': -5,
#                   'name': 'TimeToEnjoy',
#                   'previous_rating': 2473,
#                   'profile_id': 3552644,
#                   'rank': 37,
#                   'rating': 2489,
#                   'steam_id': '76561199096859133',
#                   'streak': 4,
#                   'wins': 293},
#                  {'clan': 'Biry',
#                   'country': 'AR',
#                   'drops': 8,
#                   'games': 1236,
#                   'highest_rating': 2494,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1684015568,
#                   'losses': 533,
#                   'lowest_streak': -8,
#                   'name': 'Lucky Rox',
#                   'previous_rating': 2494,
#                   'profile_id': 945852,
#                   'rank': 38,
#                   'rating': 2481,
#                   'steam_id': '76561198075555979',
#                   'streak': -1,
#                   'wins': 703},
#                  {'clan': None,
#                   'country': 'FI',
#                   'drops': 1,
#                   'games': 1036,
#                   'highest_rating': 2537,
#                   'highest_streak': 20,
#                   'icon': None,
#                   'last_match_time': 1683802703,
#                   'losses': 348,
#                   'lowest_streak': -6,
#                   'name': 'TheMax',
#                   'previous_rating': 2462,
#                   'profile_id': 572017,
#                   'rank': 39,
#                   'rating': 2479,
#                   'steam_id': '76561198426853065',
#                   'streak': 1,
#                   'wins': 688},
#                  {'clan': 'LuLe',
#                   'country': 'VN',
#                   'drops': 5,
#                   'games': 999,
#                   'highest_rating': 2541,
#                   'highest_streak': 19,
#                   'icon': None,
#                   'last_match_time': 1684238545,
#                   'losses': 359,
#                   'lowest_streak': -6,
#                   'name': '__BadBoy__',
#                   'previous_rating': 2495,
#                   'profile_id': 2503651,
#                   'rank': 40,
#                   'rating': 2476,
#                   'steam_id': '76561199041237622',
#                   'streak': -2,
#                   'wins': 640},
#                  {'clan': None,
#                   'country': 'US',
#                   'drops': 13,
#                   'games': 2684,
#                   'highest_rating': 2653,
#                   'highest_streak': 10,
#                   'icon': None,
#                   'last_match_time': 1684189372,
#                   'losses': 1294,
#                   'lowest_streak': -11,
#                   'name': 'mYi.Daniel',
#                   'previous_rating': 2444,
#                   'profile_id': 265517,
#                   'rank': 41,
#                   'rating': 2454,
#                   'steam_id': '76561198198305605',
#                   'streak': 1,
#                   'wins': 1390},
#                  {'clan': None,
#                   'country': 'CA',
#                   'drops': 17,
#                   'games': 3633,
#                   'highest_rating': 2612,
#                   'highest_streak': 14,
#                   'icon': None,
#                   'last_match_time': 1684020350,
#                   'losses': 1465,
#                   'lowest_streak': -8,
#                   'name': 'slam',
#                   'previous_rating': 2462,
#                   'profile_id': 614315,
#                   'rank': 42,
#                   'rating': 2454,
#                   'steam_id': '76561198135964589',
#                   'streak': -4,
#                   'wins': 2168},
#                  {'clan': None,
#                   'country': 'SI',
#                   'drops': 9,
#                   'games': 1034,
#                   'highest_rating': 2561,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684111736,
#                   'losses': 396,
#                   'lowest_streak': -8,
#                   'name': 'Modri',
#                   'previous_rating': 2451,
#                   'profile_id': 254415,
#                   'rank': 43,
#                   'rating': 2453,
#                   'steam_id': '76561198011417995',
#                   'streak': 1,
#                   'wins': 638},
#                  {'clan': None,
#                   'country': 'AT',
#                   'drops': 8,
#                   'games': 1249,
#                   'highest_rating': 2672,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1684157096,
#                   'losses': 508,
#                   'lowest_streak': -9,
#                   'name': 'mYi.FreakinAndy',
#                   'previous_rating': 2458,
#                   'profile_id': 1531083,
#                   'rank': 44,
#                   'rating': 2451,
#                   'steam_id': '76561198056609593',
#                   'streak': -2,
#                   'wins': 741},
#                  {'clan': None,
#                   'country': 'EE',
#                   'drops': 17,
#                   'games': 2507,
#                   'highest_rating': 2517,
#                   'highest_streak': 17,
#                   'icon': None,
#                   'last_match_time': 1684345413,
#                   'losses': 1149,
#                   'lowest_streak': -9,
#                   'name': 'Overtaken',
#                   'previous_rating': 2462,
#                   'profile_id': 4632681,
#                   'rank': 45,
#                   'rating': 2449,
#                   'steam_id': '76561198439558568',
#                   'streak': -1,
#                   'wins': 1358},
#                  {'clan': None,
#                   'country': 'DE',
#                   'drops': 20,
#                   'games': 3019,
#                   'highest_rating': 2560,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1683812447,
#                   'losses': 1292,
#                   'lowest_streak': -8,
#                   'name': 'Running',
#                   'previous_rating': 2435,
#                   'profile_id': 256338,
#                   'rank': 46,
#                   'rating': 2446,
#                   'steam_id': '76561198007187809',
#                   'streak': 2,
#                   'wins': 1727},
#                  {'clan': None,
#                   'country': 'FR',
#                   'drops': 16,
#                   'games': 3251,
#                   'highest_rating': 2524,
#                   'highest_streak': 15,
#                   'icon': None,
#                   'last_match_time': 1684269772,
#                   'losses': 1388,
#                   'lowest_streak': -9,
#                   'name': 'Babaorum',
#                   'previous_rating': 2464,
#                   'profile_id': 576919,
#                   'rank': 47,
#                   'rating': 2445,
#                   'steam_id': '76561198082024695',
#                   'streak': -2,
#                   'wins': 1863},
#                  {'clan': 'WWP',
#                   'country': 'HK',
#                   'drops': 6,
#                   'games': 1427,
#                   'highest_rating': 2505,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684327512,
#                   'losses': 618,
#                   'lowest_streak': -7,
#                   'name': 'MING',
#                   'previous_rating': 2464,
#                   'profile_id': 1966276,
#                   'rank': 48,
#                   'rating': 2445,
#                   'steam_id': '76561198376755697',
#                   'streak': -3,
#                   'wins': 809},
#                  {'clan': '1KGB1',
#                   'country': 'BR',
#                   'drops': 29,
#                   'games': 3640,
#                   'highest_rating': 2592,
#                   'highest_streak': 28,
#                   'icon': None,
#                   'last_match_time': 1684330814,
#                   'losses': 1134,
#                   'lowest_streak': -9,
#                   'name': '[KGB] F1Re',
#                   'previous_rating': 2419,
#                   'profile_id': 196310,
#                   'rank': 49,
#                   'rating': 2430,
#                   'steam_id': '76561198275970890',
#                   'streak': 6,
#                   'wins': 2506},
#                  {'clan': None,
#                   'country': 'VN',
#                   'drops': 7,
#                   'games': 2006,
#                   'highest_rating': 2484,
#                   'highest_streak': 9,
#                   'icon': None,
#                   'last_match_time': 1684334839,
#                   'losses': 908,
#                   'lowest_streak': -8,
#                   'name': 'Fish',
#                   'previous_rating': 2420,
#                   'profile_id': 2821727,
#                   'rank': 50,
#                   'rating': 2427,
#                   'steam_id': '76561199031392883',
#                   'streak': 1,
#                   'wins': 1098},
#                  {'clan': 'WWP',
#                   'country': 'CN',
#                   'drops': 13,
#                   'games': 1481,
#                   'highest_rating': 2426,
#                   'highest_streak': 9,
#                   'icon': None,
#                   'last_match_time': 1684346796,
#                   'losses': 676,
#                   'lowest_streak': -9,
#                   'name': 'Bad koala',
#                   'previous_rating': 2410,
#                   'profile_id': 211351,
#                   'rank': 51,
#                   'rating': 2426,
#                   'steam_id': '76561198262978341',
#                   'streak': 2,
#                   'wins': 805},
#                  {'clan': None,
#                   'country': 'CL',
#                   'drops': 28,
#                   'games': 1605,
#                   'highest_rating': 2446,
#                   'highest_streak': 15,
#                   'icon': None,
#                   'last_match_time': 1684044660,
#                   'losses': 639,
#                   'lowest_streak': -11,
#                   'name': 'HR Sobek',
#                   'previous_rating': 2400,
#                   'profile_id': 290617,
#                   'rank': 52,
#                   'rating': 2413,
#                   'steam_id': '76561198273707230',
#                   'streak': 4,
#                   'wins': 966},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 9,
#                   'games': 1292,
#                   'highest_rating': 2411,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1684244387,
#                   'losses': 578,
#                   'lowest_streak': -11,
#                   'name': '[MoA]DaddySt4rk',
#                   'previous_rating': 2394,
#                   'profile_id': 3884287,
#                   'rank': 53,
#                   'rating': 2411,
#                   'steam_id': '76561199101842491',
#                   'streak': 6,
#                   'wins': 714},
#                  {'clan': None,
#                   'country': 'CA',
#                   'drops': 9,
#                   'games': 1154,
#                   'highest_rating': 2452,
#                   'highest_streak': 24,
#                   'icon': None,
#                   'last_match_time': 1684098389,
#                   'losses': 463,
#                   'lowest_streak': -13,
#                   'name': 'IamChris',
#                   'previous_rating': 2405,
#                   'profile_id': 3230529,
#                   'rank': 54,
#                   'rating': 2410,
#                   'steam_id': '76561198098401046',
#                   'streak': 2,
#                   'wins': 691},
#                  {'clan': None,
#                   'country': 'RU',
#                   'drops': 20,
#                   'games': 3039,
#                   'highest_rating': 2542,
#                   'highest_streak': 9,
#                   'icon': None,
#                   'last_match_time': 1684271649,
#                   'losses': 1479,
#                   'lowest_streak': -11,
#                   'name': '3D!Dark',
#                   'previous_rating': 2428,
#                   'profile_id': 1407942,
#                   'rank': 55,
#                   'rating': 2410,
#                   'steam_id': '76561198121306763',
#                   'streak': -1,
#                   'wins': 1560},
#                  {'clan': None,
#                   'country': 'SE',
#                   'drops': 0,
#                   'games': 144,
#                   'highest_rating': 2405,
#                   'highest_streak': 32,
#                   'icon': None,
#                   'last_match_time': 1683907188,
#                   'losses': 24,
#                   'lowest_streak': -3,
#                   'name': 'Ganji',
#                   'previous_rating': 2388,
#                   'profile_id': 9555704,
#                   'rank': 56,
#                   'rating': 2405,
#                   'steam_id': '76561199242460562',
#                   'streak': 10,
#                   'wins': 120},
#                  {'clan': 'CbaG',
#                   'country': 'AR',
#                   'drops': 27,
#                   'games': 3535,
#                   'highest_rating': 2402,
#                   'highest_streak': 10,
#                   'icon': None,
#                   'last_match_time': 1683174654,
#                   'losses': 1628,
#                   'lowest_streak': -11,
#                   'name': 'deaKer',
#                   'previous_rating': 2393,
#                   'profile_id': 3022245,
#                   'rank': 57,
#                   'rating': 2402,
#                   'steam_id': '76561198026485316',
#                   'streak': 6,
#                   'wins': 1907},
#                  {'clan': None,
#                   'country': 'AR',
#                   'drops': 18,
#                   'games': 1418,
#                   'highest_rating': 2476,
#                   'highest_streak': 28,
#                   'icon': None,
#                   'last_match_time': 1684293361,
#                   'losses': 580,
#                   'lowest_streak': -7,
#                   'name': 'Nagash',
#                   'previous_rating': 2389,
#                   'profile_id': 2667231,
#                   'rank': 58,
#                   'rating': 2402,
#                   'steam_id': '76561199058636386',
#                   'streak': 4,
#                   'wins': 838},
#                  {'clan': 'Combi',
#                   'country': 'MX',
#                   'drops': 16,
#                   'games': 2195,
#                   'highest_rating': 2560,
#                   'highest_streak': 14,
#                   'icon': None,
#                   'last_match_time': 1684302018,
#                   'losses': 989,
#                   'lowest_streak': -6,
#                   'name': 'Combi | KingstoNe',
#                   'previous_rating': 2406,
#                   'profile_id': 2776293,
#                   'rank': 59,
#                   'rating': 2400,
#                   'steam_id': '76561199063069362',
#                   'streak': -1,
#                   'wins': 1206},
#                  {'clan': None,
#                   'country': 'DE',
#                   'drops': 1,
#                   'games': 574,
#                   'highest_rating': 2395,
#                   'highest_streak': 39,
#                   'icon': None,
#                   'last_match_time': 1683630739,
#                   'losses': 231,
#                   'lowest_streak': -6,
#                   'name': 'Eviscerate',
#                   'previous_rating': 2383,
#                   'profile_id': 9604749,
#                   'rank': 60,
#                   'rating': 2393,
#                   'steam_id': '76561199244204429',
#                   'streak': 1,
#                   'wins': 343},
#                  {'clan': 'NAPS',
#                   'country': 'CL',
#                   'drops': 5,
#                   'games': 474,
#                   'highest_rating': 2441,
#                   'highest_streak': 25,
#                   'icon': None,
#                   'last_match_time': 1683470250,
#                   'losses': 175,
#                   'lowest_streak': -5,
#                   'name': 'HR Whitecourt',
#                   'previous_rating': 2406,
#                   'profile_id': 5057225,
#                   'rank': 61,
#                   'rating': 2391,
#                   'steam_id': '76561199141041360',
#                   'streak': -1,
#                   'wins': 299},
#                  {'clan': 'Biry',
#                   'country': 'AR',
#                   'drops': 28,
#                   'games': 1714,
#                   'highest_rating': 2478,
#                   'highest_streak': 18,
#                   'icon': None,
#                   'last_match_time': 1684336746,
#                   'losses': 779,
#                   'lowest_streak': -9,
#                   'name': 'Twigg',
#                   'previous_rating': 2373,
#                   'profile_id': 2621722,
#                   'rank': 62,
#                   'rating': 2390,
#                   'steam_id': '76561198046946243',
#                   'streak': 1,
#                   'wins': 935},
#                  {'clan': 'Biry',
#                   'country': 'JP',
#                   'drops': 9,
#                   'games': 837,
#                   'highest_rating': 2445,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1682689777,
#                   'losses': 323,
#                   'lowest_streak': -7,
#                   'name': 'RiskyDice',
#                   'previous_rating': 2433,
#                   'profile_id': 728551,
#                   'rank': 63,
#                   'rating': 2387,
#                   'steam_id': '76561198355342951',
#                   'streak': -1,
#                   'wins': 514},
#                  {'clan': None,
#                   'country': 'CN',
#                   'drops': 1,
#                   'games': 166,
#                   'highest_rating': 2391,
#                   'highest_streak': 42,
#                   'icon': None,
#                   'last_match_time': 1683457211,
#                   'losses': 33,
#                   'lowest_streak': -3,
#                   'name': '求求你不要来伤害我',
#                   'previous_rating': 2371,
#                   'profile_id': 9873875,
#                   'rank': 64,
#                   'rating': 2387,
#                   'steam_id': '76561199260891276',
#                   'streak': 3,
#                   'wins': 133},
#                  {'clan': 'HymTr',
#                   'country': 'TR',
#                   'drops': 13,
#                   'games': 1252,
#                   'highest_rating': 2402,
#                   'highest_streak': 18,
#                   'icon': None,
#                   'last_match_time': 1684346796,
#                   'losses': 597,
#                   'lowest_streak': -10,
#                   'name': 'HOWL.Kozmonot',
#                   'previous_rating': 2402,
#                   'profile_id': 3446882,
#                   'rank': 65,
#                   'rating': 2386,
#                   'steam_id': '76561199091668803',
#                   'streak': -1,
#                   'wins': 655},
#                  {'clan': 'HymTr',
#                   'country': 'TR',
#                   'drops': 39,
#                   'games': 5332,
#                   'highest_rating': 2504,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1684261330,
#                   'losses': 2402,
#                   'lowest_streak': -9,
#                   'name': 'IW.Kasva',
#                   'previous_rating': 2392,
#                   'profile_id': 1224481,
#                   'rank': 66,
#                   'rating': 2386,
#                   'steam_id': '76561198368620113',
#                   'streak': -1,
#                   'wins': 2930},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 12,
#                   'games': 1489,
#                   'highest_rating': 2426,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684284272,
#                   'losses': 594,
#                   'lowest_streak': -8,
#                   'name': 'twitch.tv/st4rk_',
#                   'previous_rating': 2404,
#                   'profile_id': 986504,
#                   'rank': 67,
#                   'rating': 2384,
#                   'steam_id': '76561198169764954',
#                   'streak': -2,
#                   'wins': 895},
#                  {'clan': 'C1own',
#                   'country': 'CZ',
#                   'drops': 64,
#                   'games': 7530,
#                   'highest_rating': 2588,
#                   'highest_streak': 15,
#                   'icon': None,
#                   'last_match_time': 1684253313,
#                   'losses': 3286,
#                   'lowest_streak': -13,
#                   'name': 'CL.DracKeN',
#                   'previous_rating': 2372,
#                   'profile_id': 357795,
#                   'rank': 68,
#                   'rating': 2384,
#                   'steam_id': '76561198367209710',
#                   'streak': 1,
#                   'wins': 4244},
#                  {'clan': 'LuLe',
#                   'country': 'VN',
#                   'drops': 33,
#                   'games': 2959,
#                   'highest_rating': 2501,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684335726,
#                   'losses': 1469,
#                   'lowest_streak': -11,
#                   'name': 'Thành Cổ Quảng Trị &lt;Hope&gt;',
#                   'previous_rating': 2352,
#                   'profile_id': 2660491,
#                   'rank': 69,
#                   'rating': 2371,
#                   'steam_id': '76561199054206296',
#                   'streak': 1,
#                   'wins': 1490},
#                  {'clan': None,
#                   'country': 'BR',
#                   'drops': 65,
#                   'games': 3214,
#                   'highest_rating': 2468,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1684292618,
#                   'losses': 1476,
#                   'lowest_streak': -10,
#                   'name': 'bruh',
#                   'previous_rating': 2346,
#                   'profile_id': 2135484,
#                   'rank': 70,
#                   'rating': 2362,
#                   'steam_id': '76561199035860327',
#                   'streak': 7,
#                   'wins': 1738},
#                  {'clan': None,
#                   'country': 'PL',
#                   'drops': 33,
#                   'games': 1503,
#                   'highest_rating': 2473,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684343231,
#                   'losses': 656,
#                   'lowest_streak': -9,
#                   'name': 'JackK',
#                   'previous_rating': 2341,
#                   'profile_id': 452924,
#                   'rank': 71,
#                   'rating': 2354,
#                   'steam_id': '76561198033713695',
#                   'streak': 1,
#                   'wins': 847},
#                  {'clan': None,
#                   'country': 'IN',
#                   'drops': 45,
#                   'games': 2334,
#                   'highest_rating': 2502,
#                   'highest_streak': 15,
#                   'icon': None,
#                   'last_match_time': 1684339862,
#                   'losses': 937,
#                   'lowest_streak': -9,
#                   'name': 'The_Dragonstar',
#                   'previous_rating': 2336,
#                   'profile_id': 182749,
#                   'rank': 72,
# ...
#                   'games': 3282,
#                   'highest_rating': 2442,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1684198910,
#                   'losses': 1550,
#                   'lowest_streak': -8,
#                   'name': '_Hallis',
#                   'previous_rating': 2320,
#                   'profile_id': 250103,
#                   'rank': 77,
#                   'rating': 2334,
#                   'steam_id': '76561198061054857',
#                   'streak': 5,
#                   'wins': 1732},
#                  {'clan': 'Biry',
#                   'country': 'AR',
#                   'drops': 7,
#                   'games': 2403,
#                   'highest_rating': 2345,
#                   'highest_streak': 23,
#                   'icon': None,
#                   'last_match_time': 1684275807,
#                   'losses': 1149,
#                   'lowest_streak': -8,
#                   'name': 'DS_Levi',
#                   'previous_rating': 2314,
#                   'profile_id': 2821779,
#                   'rank': 78,
#                   'rating': 2327,
#                   'steam_id': '76561199065337729',
#                   'streak': 5,
#                   'wins': 1254},
#                  {'clan': 'C1own',
#                   'country': 'NL',
#                   'drops': 24,
#                   'games': 2807,
#                   'highest_rating': 2355,
#                   'highest_streak': 9,
#                   'icon': None,
#                   'last_match_time': 1684180104,
#                   'losses': 1328,
#                   'lowest_streak': -8,
#                   'name': 'CL.D3rp',
#                   'previous_rating': 2315,
#                   'profile_id': 212294,
#                   'rank': 79,
#                   'rating': 2325,
#                   'steam_id': '76561198169336974',
#                   'streak': 4,
#                   'wins': 1479},
#                  {'clan': None,
#                   'country': 'MX',
#                   'drops': 8,
#                   'games': 770,
#                   'highest_rating': 2367,
#                   'highest_streak': 19,
#                   'icon': None,
#                   'last_match_time': 1682706007,
#                   'losses': 339,
#                   'lowest_streak': -6,
#                   'name': 'KH_GameOnline',
#                   'previous_rating': 2367,
#                   'profile_id': 6345180,
#                   'rank': 80,
#                   'rating': 2324,
#                   'steam_id': '76561199201775338',
#                   'streak': 5,
#                   'wins': 431},
#                  {'clan': None,
#                   'country': 'CN',
#                   'drops': 2,
#                   'games': 352,
#                   'highest_rating': 2456,
#                   'highest_streak': 30,
#                   'icon': None,
#                   'last_match_time': 1684256660,
#                   'losses': 101,
#                   'lowest_streak': -8,
#                   'name': '猪头',
#                   'previous_rating': 2311,
#                   'profile_id': 9695965,
#                   'rank': 81,
#                   'rating': 2320,
#                   'steam_id': '76561199248045654',
#                   'streak': 1,
#                   'wins': 251},
#                  {'clan': 'xxdg',
#                   'country': 'CN',
#                   'drops': 61,
#                   'games': 1611,
#                   'highest_rating': 2350,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684330510,
#                   'losses': 754,
#                   'lowest_streak': -8,
#                   'name': '旋律',
#                   'previous_rating': 2298,
#                   'profile_id': 2972505,
#                   'rank': 82,
#                   'rating': 2318,
#                   'steam_id': '76561199003998451',
#                   'streak': 1,
#                   'wins': 857},
#                  {'clan': 'FrCo',
#                   'country': 'FR',
#                   'drops': 8,
#                   'games': 1029,
#                   'highest_rating': 2340,
#                   'highest_streak': 10,
#                   'icon': None,
#                   'last_match_time': 1683380988,
#                   'losses': 443,
#                   'lowest_streak': -7,
#                   'name': 'Cl3m3nT',
#                   'previous_rating': 2329,
#                   'profile_id': 245117,
#                   'rank': 83,
#                   'rating': 2317,
#                   'steam_id': '76561198078010430',
#                   'streak': -2,
#                   'wins': 586},
#                  {'clan': 'CbaG',
#                   'country': 'AR',
#                   'drops': 12,
#                   'games': 979,
#                   'highest_rating': 2383,
#                   'highest_streak': 10,
#                   'icon': None,
#                   'last_match_time': 1684300484,
#                   'losses': 447,
#                   'lowest_streak': -7,
#                   'name': 'deaKer Casillas',
#                   'previous_rating': 2301,
#                   'profile_id': 5170240,
#                   'rank': 84,
#                   'rating': 2317,
#                   'steam_id': '76561199145732014',
#                   'streak': 2,
#                   'wins': 532},
#                  {'clan': None,
#                   'country': 'CO',
#                   'drops': 78,
#                   'games': 10759,
#                   'highest_rating': 2400,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684259361,
#                   'losses': 5278,
#                   'lowest_streak': -10,
#                   'name': 'Ozone',
#                   'previous_rating': 2298,
#                   'profile_id': 2654577,
#                   'rank': 85,
#                   'rating': 2314,
#                   'steam_id': '76561198826220092',
#                   'streak': 3,
#                   'wins': 5481},
#                  {'clan': None,
#                   'country': 'IT',
#                   'drops': 7,
#                   'games': 813,
#                   'highest_rating': 2354,
#                   'highest_streak': 13,
#                   'icon': None,
#                   'last_match_time': 1682973600,
#                   'losses': 382,
#                   'lowest_streak': -9,
#                   'name': 'Shades',
#                   'previous_rating': 2354,
#                   'profile_id': 2462063,
#                   'rank': 86,
#                   'rating': 2312,
#                   'steam_id': '76561199050788934',
#                   'streak': 3,
#                   'wins': 431},
#                  {'clan': None,
#                   'country': 'CO',
#                   'drops': 0,
#                   'games': 366,
#                   'highest_rating': 2353,
#                   'highest_streak': 22,
#                   'icon': None,
#                   'last_match_time': 1684091085,
#                   'losses': 142,
#                   'lowest_streak': -6,
#                   'name': 'Ozone v2.0',
#                   'previous_rating': 2298,
#                   'profile_id': 11962856,
#                   'rank': 87,
#                   'rating': 2311,
#                   'steam_id': '76561198237386056',
#                   'streak': 3,
#                   'wins': 224},
#                  {'clan': None,
#                   'country': 'MX',
#                   'drops': 21,
#                   'games': 789,
#                   'highest_rating': 2358,
#                   'highest_streak': 11,
#                   'icon': None,
#                   'last_match_time': 1684044660,
#                   'losses': 341,
#                   'lowest_streak': -8,
#                   'name': 'Combi | CasaBlancas',
#                   'previous_rating': 2323,
#                   'profile_id': 3317764,
#                   'rank': 88,
#                   'rating': 2310,
#                   'steam_id': '76561199084646199',
#                   'streak': -3,
#                   'wins': 448},
#                  {'clan': 'AUNZ',
#                   'country': 'NZ',
#                   'drops': 0,
#                   'games': 641,
#                   'highest_rating': 2308,
#                   'highest_streak': 14,
#                   'icon': None,
#                   'last_match_time': 1684063599,
#                   'losses': 259,
#                   'lowest_streak': -8,
#                   'name': 'flightlessbird',
#                   'previous_rating': 2292,
#                   'profile_id': 285508,
#                   'rank': 89,
#                   'rating': 2308,
#                   'steam_id': '76561198055096506',
#                   'streak': 3,
#                   'wins': 382},
#                  {'clan': None,
#                   'country': 'DE',
#                   'drops': 21,
#                   'games': 6459,
#                   'highest_rating': 2485,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684336708,
#                   'losses': 3148,
#                   'lowest_streak': -11,
#                   'name': 'El_Matador',
#                   'previous_rating': 2295,
#                   'profile_id': 230475,
#                   'rank': 90,
#                   'rating': 2308,
#                   'steam_id': '76561198068729026',
#                   'streak': 2,
#                   'wins': 3311},
#                  {'clan': 'Liiit',
#                   'country': 'DE',
#                   'drops': 8,
#                   'games': 2293,
#                   'highest_rating': 2472,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1682857680,
#                   'losses': 1066,
#                   'lowest_streak': -11,
#                   'name': 'GL.Nili',
#                   'previous_rating': 2349,
#                   'profile_id': 197751,
#                   'rank': 91,
#                   'rating': 2307,
#                   'steam_id': '76561197964180873',
#                   'streak': -1,
#                   'wins': 1227},
#                  {'clan': 'RANK1',
#                   'country': 'ES',
#                   'drops': 16,
#                   'games': 2843,
#                   'highest_rating': 2306,
#                   'highest_streak': 14,
#                   'icon': None,
#                   'last_match_time': 1684069225,
#                   'losses': 1376,
#                   'lowest_streak': -8,
#                   'name': 'm0re',
#                   'previous_rating': 2292,
#                   'profile_id': 279036,
#                   'rank': 92,
#                   'rating': 2306,
#                   'steam_id': '76561198314917416',
#                   'streak': 3,
#                   'wins': 1467},
#                  {'clan': None,
#                   'country': 'US',
#                   'drops': 1,
#                   'games': 299,
#                   'highest_rating': 2303,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1684041347,
#                   'losses': 107,
#                   'lowest_streak': -5,
#                   'name': 'Hasan',
#                   'previous_rating': 2284,
#                   'profile_id': 2032611,
#                   'rank': 93,
#                   'rating': 2303,
#                   'steam_id': '76561199038649194',
#                   'streak': 1,
#                   'wins': 192},
#                  {'clan': 'WE4SC',
#                   'country': 'CN',
#                   'drops': 15,
#                   'games': 1470,
#                   'highest_rating': 2421,
#                   'highest_streak': 29,
#                   'icon': None,
#                   'last_match_time': 1684252159,
#                   'losses': 677,
#                   'lowest_streak': -9,
#                   'name': '抖音帝国时代痛大师',
#                   'previous_rating': 2280,
#                   'profile_id': 6268226,
#                   'rank': 94,
#                   'rating': 2297,
#                   'steam_id': '76561199197809267',
#                   'streak': 1,
#                   'wins': 793},
#                  {'clan': None,
#                   'country': 'MX',
#                   'drops': 13,
#                   'games': 1111,
#                   'highest_rating': 2473,
#                   'highest_streak': 27,
#                   'icon': None,
#                   'last_match_time': 1684292555,
#                   'losses': 523,
#                   'lowest_streak': -7,
#                   'name': 'Combi | 7Swords',
#                   'previous_rating': 2310,
#                   'profile_id': 4785288,
#                   'rank': 95,
#                   'rating': 2297,
#                   'steam_id': '76561199129096097',
#                   'streak': -3,
#                   'wins': 588},
#                  {'clan': 'SECRT',
#                   'country': 'TR',
#                   'drops': 19,
#                   'games': 959,
#                   'highest_rating': 2296,
#                   'highest_streak': 19,
#                   'icon': None,
#                   'last_match_time': 1684325728,
#                   'losses': 445,
#                   'lowest_streak': -10,
#                   'name': 'Muhammed',
#                   'previous_rating': 2278,
#                   'profile_id': 3500355,
#                   'rank': 96,
#                   'rating': 2296,
#                   'steam_id': '76561199094094413',
#                   'streak': 3,
#                   'wins': 514},
#                  {'clan': 'ALL',
#                   'country': 'JP',
#                   'drops': 9,
#                   'games': 1205,
#                   'highest_rating': 2431,
#                   'highest_streak': 11,
#                   'icon': None,
#                   'last_match_time': 1684247713,
#                   'losses': 514,
#                   'lowest_streak': -10,
#                   'name': 'chart',
#                   'previous_rating': 2305,
#                   'profile_id': 217905,
#                   'rank': 97,
#                   'rating': 2296,
#                   'steam_id': '76561198116269715',
#                   'streak': -1,
#                   'wins': 691},
#                  {'clan': 'CiD',
#                   'country': 'DE',
#                   'drops': 17,
#                   'games': 2411,
#                   'highest_rating': 2295,
#                   'highest_streak': 12,
#                   'icon': None,
#                   'last_match_time': 1684285170,
#                   'losses': 1160,
#                   'lowest_streak': -7,
#                   'name': 'Suryavarman',
#                   'previous_rating': 2286,
#                   'profile_id': 3712481,
#                   'rank': 98,
#                   'rating': 2295,
#                   'steam_id': '76561199099403556',
#                   'streak': 4,
#                   'wins': 1251},
#                  {'clan': 'WWP',
#                   'country': 'CN',
#                   'drops': 36,
#                   'games': 3161,
#                   'highest_rating': 2379,
#                   'highest_streak': 10,
#                   'icon': None,
#                   'last_match_time': 1684328457,
#                   'losses': 1512,
#                   'lowest_streak': -8,
#                   'name': '勇敢熊熊',
#                   'previous_rating': 2284,
#                   'profile_id': 243287,
#                   'rank': 99,
#                   'rating': 2294,
#                   'steam_id': '76561198297171662',
#                   'streak': 2,
#                   'wins': 1649},
#                  {'clan': None,
#                   'country': 'RU',
#                   'drops': 16,
#                   'games': 1838,
#                   'highest_rating': 2462,
#                   'highest_streak': 16,
#                   'icon': None,
#                   'last_match_time': 1683902518,
#                   'losses': 870,
#                   'lowest_streak': -10,
#                   'name': 'repard',
#                   'previous_rating': 2313,
#                   'profile_id': 222528,
#                   'rank': 100,
#                   'rating': 2292,
#                   'steam_id': '76561198034782642',
#                   'streak': -2,
#                   'wins': 968}],
#  'leaderboard_id': 3,
#  'start': 1,
#  'total': 47122}

# %% [markdown]
# Následující jsou příklady webů a služeb, které nabízejí API a jsou poměrně snadno dostupné pro vyzkoušení:
#
# <br>
#
# * **Twitter API** - Twitter API umožňuje vývojářům přistupovat k datům a funkcím Twitteru. Můžete si například vytvořit aplikaci, která bude zobrazovat nejnovější tweety z vašeho účtu.
#
# * **Google Maps API** - Google Maps API umožňuje vývojářům integrovat mapy a geografická data do svých aplikací. Můžete si například vytvořit aplikaci, která bude zobrazovat nejlepší trasy pro pěší, cyklisty nebo řidiče.
#
# * **OpenWeatherMap API** - OpenWeatherMap API umožňuje získat přesné informace o počasí pro libovolné místo na světě. Můžete si například vytvořit aplikaci, která bude zobrazovat aktuální teplotu a předpověď počasí pro váš region.
#
# * **Flickr API** - Flickr API umožňuje vývojářům přistupovat k obrázkům a videím na Flickr. Můžete si například vytvořit aplikaci, která bude zobrazovat nejnovější fotografie z vašeho účtu.
#
# * **YouTube API** - YouTube API umožňuje vývojářům přistupovat k videím a funkcím na YouTube. Můžete si například vytvořit aplikaci, která bude zobrazovat nejnovější videa z vašeho účtu nebo z vašeho oblíbeného kanálu.
#
# <br>
#
# Tyto weby a služby nabízejí API s různou úrovní složitosti, takže můžete najít to, co bude nejlepší pro vaše potřeby a úroveň zkušeností.
